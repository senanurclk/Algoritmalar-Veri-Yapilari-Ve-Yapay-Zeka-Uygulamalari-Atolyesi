# %%
print("Merhaba, Python Veri Yapıları ve Algoritmalar / Ders 3")
# Out:
# Merhaba, Python Veri Yapıları ve Algoritmalar / Ders 3

# %%
import sys  # import python programlama dilinde yazılıma kütüphane eklemeye yarayan bir kod blogudur.
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
from google.colab import drive # google colab - drive bağlantısı

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir('/content/drive/My Drive/GoogleColab')

# !pwd # bize kodun çıktısını dosya yolu olarak veren kod blogudur.
# Out:
# /content/drive/My Drive/GoogleColab

# %%
# geçerli bir değişken tanımı

degisken1 = 10

Degisken2 = 20

degisken_3 = 30

_degisken_4 = 40

print(degisken1)
print(Degisken2)
print(degisken_3)
print(_degisken_4)
# Out:
# 10
# 20
# 30
# 40

# %%
#gecersiz değişken tanımlaması

# 1degisken = 50

# degisken1-4 = 50

# %%
x = 5

y = "Merhaba Dünya"

print(x)

print(y)
# Out:
# 5
# Merhaba Dünya

# %%
print(x)
print(x+5)
# Out:
# 5
# 10

# %%
a = 10 #atama operatörü (=) eşittir (==)

print(type(a), a)
# Out:
# <class 'int'> 10

# %%
b = 20.5

print(type(b), b)
# Out:
# <class 'float'> 20.5

# %%
# int veri tipinden float'a çevirim işlemi örneği

y = 10

x = float(y)

print(x, type(x))
# Out:
# 10.0 <class 'float'>

# %%
# float veri tipinden int veri tipine çevirim örneği

y = 10.74   # int bunun float kısmını atıyor

x = int(y)

print(x, type(x))
# Out:
# 10 <class 'int'>

# %%
# String - metinsel bilgiyi değişkene atama işlemi

c = "Python Programlama"

print(c, type(c))
# Out:
# Python Programlama <class 'str'>

# %%
# Boolean (True / Doğru - False / Yanlış) Değişken tanımlaması

d = True # 1 - Aktif
e = False # 0 - Pasif

print(d)
print(type(e))
# Out:
# True
# <class 'bool'>

# %%
# List - liste --> Dizi tanımlaması

liste = [1, 2, 3, 4, 5] # list de ekleme çıkarma yapabiliyorsun

print(type(liste), liste)
liste[0] = 100
print(liste[0])
print(liste)
# Out:
# <class 'list'> [1, 2, 3, 4, 5]
# 100
# [100, 2, 3, 4, 5]

# %%
# Demet - Tuple Veri Tipi Tanımlaması

demet = (1, 2, 3, 4, 5) # tuple da ekleme çıkarma yapamıyorsun / sabit veriler için / eleman değitirme de yapamıyorsun

print(type(demet), demet)
# Out:
# <class 'tuple'> (1, 2, 3, 4, 5)

# %%
# Dictionary - Sözlük Veri Tipi Tanımlaması --> Öğrenci Notlarını Tutan bir sözlük tanımlaması

# olmayan öğrencilerin de bilgileri tutulabilir

notlar = {
    "Ali": 85,
    "Veli": 90,
    "Ayşe": 78
}

notlar["Fatma"] = 95 # yeni öğrenci ekleme yöntemi
notlar["Ali"] = 88 # mevcuttaki öğrencinin notunu günleme işlemi

print(notlar)
# Out:
# {'Ali': 88, 'Veli': 90, 'Ayşe': 78, 'Fatma': 95}

# %%
# Set Küme veri tipi

kodyazanlar = {"Ahmet", "Mehmet", "Ayşe"}
kodyazmayanlar = {"Ayşe", "Fatma", "Veli"}

ortak = kodyazanlar.intersection(kodyazmayanlar) # İki kümenin ortak elemanlarını verir. Yani “ikisinde de olanlar”
print("Kafasına Göre Takılan Arkadaşlar: ", ortak)

kod_yazmayanlar = kodyazmayanlar.difference(kodyazanlar) # Bir kümede olup diğerinde olmayan elemanları verir. “A’da var ama B’de yok”
print("Kod çalışması yapmayanlar: ", kod_yazmayanlar)

imzalistesi = kodyazanlar.union(kodyazmayanlar) # İki kümedeki tüm elemanları (tekrarsız) birleştirir.“İkisindeki her şey”
print("Sınıf İmza Listesi: ", imzalistesi)
# Out:
# Kafasına Göre Takılan Arkadaşlar:  {'Ayşe'}
# Kod çalışması yapmayanlar:  {'Veli', 'Fatma'}
# Sınıf İmza Listesi:  {'Ahmet', 'Veli', 'Ayşe', 'Mehmet', 'Fatma'}

# %%
giris = input("Bir Sayı Giriniz:") # 12345 dediğimizde bu şu an string eğer int yapmak istiyorsak tür dönüşümü yapacağız

print(giris)
print(type(giris))
print(type(int(giris)))
# Out:
# Bir Sayı Giriniz:12345
# 12345
# <class 'str'>
# <class 'int'>

# %%
giris = input("Bir Sayı Giriniz:")
try: # try except yazarsan koddan önce bir düzenlemiş olursun ne veri almak istediğini. try bloğu → Hata çıkma ihtimali olan kodu yazarsın
# except bloğu → Eğer hata olursa ne yapılacağını yazarsın
    numara = float(giris)
    print("Girilen Sayı: ", numara)
except ValueError:
    print("Hatalı Bilgi Girişi Yaptınız Lütfen Tekrar Deneyiniz!")
# Out:
# Bir Sayı Giriniz:12
# Girilen Sayı:  12.0

# %%
import random

rastgele = random.random() # random fonksiyonu bize 0 ile 1 arasında rastgele bir sayı üreten fonksiyondur.

print("Rastgele Gelen Deger: ", rastgele)
# Out:
# Rastgele Gelen Deger:  0.10890806521829599

# %%
import random

rastgele2 = random.randint(1, 100) # randint fonksiyonu bize istediğimiz aralıkta rastgele bir sayı üreten fonksiyondur.

print("Rastgele Gelen Deger: ", rastgele2)
# Out:
# Rastgele Gelen Deger:  48
